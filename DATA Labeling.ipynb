# %%
import math
import pandas as pd

from google.colab import drive
drive.mount('/content/drive')

import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/Appunti/TXA/TXA Alleluja_data.csv')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 0    21413
# 1     6226
# Name: sentiment, dtype: int64
# Maximum Valence: 5.0
# Maximum Dominance: 5.0
# Maximum Arousal: 5.0

# %% [markdown]
# * 2.5 seems like too low a threshold, it returns 420 positive results out of 27369
# * 5.0 returns 7785 positive results (28%)
# * 4.5 returns 4794 (17%)
# ![image.png](attachment:image.png)

# %%
def sentiment(row):

    valence = row[5]
    arousal = row[6]
    dominance = row[7]

#valence <= 5.8 and dominance <= 6.4 for 50/50 - 6,6,6 works too
# valence <= 6.6 and dominance <= 6.89 best results so far

    if valence <= 5 and dominance <= 5 and arousal <= 5:
        return 1
    else:
        return 0

df['sentiment'] = df.apply(sentiment, axis=1)


portions = df.groupby(['sentiment']).count()

positives = df[df['sentiment'] == 1].shape[0]
whole = len(df)
percentage = (positives / whole) * 100

print(f"=====================\n Class1 = {math.floor(percentage)}% of dataset \n=====================")
portions['lyrics']
# Out:
# ...
#  Class1 = 22% of dataset
# ...
# sentiment
# 0    21413
# 1     6226
# Name: lyrics, dtype: int64

# %%
#df.to_csv("dataset.csv")
